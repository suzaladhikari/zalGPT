# %%
import os

size = os.path.getsize("../localgpt/data/TinyStories-train.txt")

print(f"{size / (1024**3):.2f} GB")
# Out:
# 1.79 GB

# %%
import tiktoken 
enc = tiktoken.get_encoding('gpt2')
# Out:
# c:\Users\SAdhikari4\anaconda3\envs\galGPT\Lib\site-packages\requests\__init__.py:92: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import torch 
print(torch.randint(1000-9, (9,)))
# Out:
# tensor([458,   9,  95, 622, 730, 579,  53, 859, 530])

# %%
print(456+256)
# Out:
# 712
